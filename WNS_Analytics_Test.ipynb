# %%
# %matplotlib inline
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')
import numpy as np
from pandas import Series

# %%
data = pd.read_csv(r"C:/01 Projects/07 Personal_Projects/06 Hackathon/01_WNS_Analytics_Wizard/train_NA17Sgz/train.csv")
data.shape
# Out:
# (237609, 7)

# %%
data.head()
# Out:
#                       impression_id      impression_time  user_id  app_code  \
# 0  c4ca4238a0b923820dcc509a6f75849b  2018-11-15 00:00:00    87862       422
# 1  45c48cce2e2d7fbdea1afc51c7c6ad26  2018-11-15 00:01:00    63410       467
# 2  70efdf2ec9b086079795c442636b55fb  2018-11-15 00:02:00    71748       259
# 3  8e296a067a37563370ded05f5a3bf3ec  2018-11-15 00:02:00    69209       244
# 4  182be0c5cdcd5072bb1864cdee4d3d6e  2018-11-15 00:02:00    62873       473
#
#      os_version  is_4G  is_click
# 0           old      0         0
# 1        latest      1         1
# 2  intermediate      1         0
# 3        latest      1         0
# 4        latest      0         0

# %%
data.impression_time = pd.to_datetime(data.impression_time)

# %%
data.head(100)
# Out:
#                        impression_id     impression_time  user_id  app_code  \
# 0   c4ca4238a0b923820dcc509a6f75849b 2018-11-15 00:00:00    87862       422
# 1   45c48cce2e2d7fbdea1afc51c7c6ad26 2018-11-15 00:01:00    63410       467
# 2   70efdf2ec9b086079795c442636b55fb 2018-11-15 00:02:00    71748       259
# 3   8e296a067a37563370ded05f5a3bf3ec 2018-11-15 00:02:00    69209       244
# 4   182be0c5cdcd5072bb1864cdee4d3d6e 2018-11-15 00:02:00    62873       473
# 5   3416a75f4cea9109507cacd8e2f2aefc 2018-11-15 00:03:00    67352       409
# 6   f457c545a9ded88f18ecee47145a72c0 2018-11-15 00:03:00    64356       190
# 7   72b32a1f754ba1c09b3695e0cb6cde7f 2018-11-15 00:04:00    27329       481
# 8   fc490ca45c00b1249bbe3554a4fdf6fb 2018-11-15 00:05:00    83318       386
# 9   d2ddea18f00665ce8623e36bd4e3c7c5 2018-11-15 00:05:00    70206       190
# 10  43ec517d68b6edd3015b3edc9a11367b 2018-11-15 00:06:00    74339       481
# ...

# %%
data.dtypes
# Out:
# impression_id              object
# impression_time    datetime64[ns]
# user_id                     int64
# app_code                    int64
# os_version                 object
# is_4G                       int64
# is_click                    int64
# dtype: object

# %%
data.is_click.mean()
# Out:
# 0.04571375663379754

# %%
data.is_4G.mean()
# Out:
# 0.3613120715124427

# %%
data[data.is_4G == 1].is_click.mean()
# Out:
# 0.04475195396675636

# %%
data[data.is_4G == 0].is_click.mean()
# Out:
# 0.04625785790534931

# %%
data.groupby("is_4G").is_click.mean()
# Out:
# is_4G
# 0    0.046258
# 1    0.044752
# Name: is_click, dtype: float64

# %%
data.groupby("os_version").is_click.mean()
# Out:
# os_version
# intermediate    0.051762
# latest          0.041651
# old             0.049290
# Name: is_click, dtype: float64

# %%
appcodemean = data.groupby("app_code").is_click.mean()

# %%
appcodedf.reset_index(level=0, inplace=True)

# %%
data.head()
# Out:
#                       impression_id     impression_time  user_id  app_code  \
# 0  c4ca4238a0b923820dcc509a6f75849b 2018-11-15 00:00:00    87862       422
# 1  45c48cce2e2d7fbdea1afc51c7c6ad26 2018-11-15 00:01:00    63410       467
# 2  70efdf2ec9b086079795c442636b55fb 2018-11-15 00:02:00    71748       259
# 3  8e296a067a37563370ded05f5a3bf3ec 2018-11-15 00:02:00    69209       244
# 4  182be0c5cdcd5072bb1864cdee4d3d6e 2018-11-15 00:02:00    62873       473
#
#      os_version  is_4G  is_click
# 0           old      0         0
# 1        latest      1         1
# 2  intermediate      1         0
# 3        latest      1         0
# 4        latest      0         0

# %%
data.head(5)
# Out:
#                       impression_id     impression_time  user_id  app_code  \
# 0  c4ca4238a0b923820dcc509a6f75849b 2018-11-15 00:00:00    87862       422
# 1  45c48cce2e2d7fbdea1afc51c7c6ad26 2018-11-15 00:01:00    63410       467
# 2  70efdf2ec9b086079795c442636b55fb 2018-11-15 00:02:00    71748       259
# 3  8e296a067a37563370ded05f5a3bf3ec 2018-11-15 00:02:00    69209       244
# 4  182be0c5cdcd5072bb1864cdee4d3d6e 2018-11-15 00:02:00    62873       473
#
#      os_version  is_4G  is_click
# 0           old      0         0
# 1        latest      1         1
# 2  intermediate      1         0
# 3        latest      1         0
# 4        latest      0         0

# %%
appcodedf[appcodedf.app_code==0]
# Out:
#    level_0  index  app_code  is_click
# 0        0      0         0  0.082192

# %%
new_df = pd.DataFrame(data.impression_time,data.is_click)

# %%
new_df.reset_index(level=0, inplace=True)

# %%
new_df.shape
# Out:
# (237609, 3)

# %%
data["day"] = data["impression_time"].dt.dayofweek

# %%
data.head(10000)
# Out:
#                          impression_id     impression_time  user_id  app_code  \
# 0     c4ca4238a0b923820dcc509a6f75849b 2018-11-15 00:00:00    87862       422
# 1     45c48cce2e2d7fbdea1afc51c7c6ad26 2018-11-15 00:01:00    63410       467
# 2     70efdf2ec9b086079795c442636b55fb 2018-11-15 00:02:00    71748       259
# 3     8e296a067a37563370ded05f5a3bf3ec 2018-11-15 00:02:00    69209       244
# 4     182be0c5cdcd5072bb1864cdee4d3d6e 2018-11-15 00:02:00    62873       473
# 5     3416a75f4cea9109507cacd8e2f2aefc 2018-11-15 00:03:00    67352       409
# 6     f457c545a9ded88f18ecee47145a72c0 2018-11-15 00:03:00    64356       190
# 7     72b32a1f754ba1c09b3695e0cb6cde7f 2018-11-15 00:04:00    27329       481
# 8     fc490ca45c00b1249bbe3554a4fdf6fb 2018-11-15 00:05:00    83318       386
# 9     d2ddea18f00665ce8623e36bd4e3c7c5 2018-11-15 00:05:00    70206       190
# 10    43ec517d68b6edd3015b3edc9a11367b 2018-11-15 00:06:00    74339       481
# ...

# %%
data.groupby("day").is_click.mean()
# Out:
# day
# 0    0.046698
# 1    0.043007
# 2    0.044517
# 3    0.045868
# 4    0.044730
# 5    0.048106
# 6    0.047977
# Name: is_click, dtype: float64

# %%
data.head()
# Out:
#                       impression_id     impression_time  user_id  app_code  \
# 0  c4ca4238a0b923820dcc509a6f75849b 2018-11-15 00:00:00    87862       422
# 1  45c48cce2e2d7fbdea1afc51c7c6ad26 2018-11-15 00:01:00    63410       467
# 2  70efdf2ec9b086079795c442636b55fb 2018-11-15 00:02:00    71748       259
# 3  8e296a067a37563370ded05f5a3bf3ec 2018-11-15 00:02:00    69209       244
# 4  182be0c5cdcd5072bb1864cdee4d3d6e 2018-11-15 00:02:00    62873       473
#
#      os_version  is_4G  is_click  day
# 0           old      0         0    3
# 1        latest      1         1    3
# 2  intermediate      1         0    3
# 3        latest      1         0    3
# 4        latest      0         0    3
