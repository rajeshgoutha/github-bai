# %% [markdown]
# ##### Assignment 1

# %% [markdown]
# ##### Question 1
# 1.	Suppose the cover price of a book is Rs. 200, but bookstores get a 25% discount. Shipping costs Rs. 40 for the first copy and Rs. 10 for each additional copy. Write a Python program to calculate the total wholesale cost for 60 copies. [8 Marks]
#
# ##### Sol:

# %%
# Define a function for calculating the whole sale cost for n books
def get_whole_sale_cost(no_of_copies):
    cover_price = 200
    whole_sale_cost = 200 * 0.75 * no_of_copies + 10 * (no_of_copies-1) + 40
    return whole_sale_cost

print("Whole sale cost for 60 copies is: ", get_whole_sale_cost(60))
# Out:
# Whole sale cost for 60 copies is:  9630.0

# %% [markdown]
# ##### Question 2
# 2.	A number, x, is a power of y if it is divisible by y and x/y is a power of y. Write a function in Python that takes parameters x and y and returns True if x is a power of y. [8 Marks]
# ##### Sol:

# %%
# Define a function to return true if x is power of y
def check_if_x_ispowerof_y(x,y):
    if(x==1):
        return True
    else:
        z=1
        while(z < x):
            z *= y
        return (z == x)
x = int(input("Enter value of x"))
y = int(input("Enter value of y"))
print("Is x power of y: ", check_if_x_ispowerof_y(x,y))
# Out:
# Enter value of x125
# Enter value of y5
# Is x power of y:  True

# %% [markdown]
# ##### Question 3
# 3.	Write a function in Python that takes three parameters a, b, and c and returns their greatest common divisor. [8 Marks]
# ##### Sol:

# %%
# Define a function to return GCD of two parameters a and b
def gcd2(a,b):
    if(a==0):
        return b
    return gcd2(b % a, a)

# Define a function to return GCD of three parameters using gcd2 function defined above
def gcd(a,b,c):
    res = gcd2(a,b)
    return(gcd2(res,c))

a = int(input("Enter value of a "))
b = int(input("Enter value of b "))
c = int(input("Enter value of c "))
print("GCD of: ",a,",", b ,",", c, "is: ",gcd(a,b,c))
# Out:
# Enter value of a 80
# Enter value of b 40
# Enter value of c 20
# GCD of:  80 , 40 , 20 is:  20

# %% [markdown]
# ##### Question 4
# 4.	Write a Python script that reads the current time and converts it to a time of day in hours, minutes, and seconds, plus the number of days since the epoch. [8 Marks]
# ##### Sol:

# %%
from datetime import datetime
import time
now = datetime.now()
# Format the date to a time of day in hours, minutes and seconds
formatted_date = now.strftime("%H, %M, %S")
print("Time of day in hours, minutes,seconds :", formatted_date)

# Get the number of seconds elapsed since the epoch using time.time() and then divide it by 86400 to get the number of seconds
seconds_since_epoch = time.time()
days_since_epoch = seconds_since_epoch/86400
print("Number of days since the epoch",round(days_since_epoch,2))
# Out:
# Time of day in hours, minutes,seconds : 19, 04, 55
# Number of days since the epoch 18147.57

# %% [markdown]
# ##### Question 5
# 5.	Write a function in Python that takes three integers as arguments, and that prints either “Yes” or “No”, depending on whether you can or cannot form a triangle from the given lengths. [8 Marks]
# Hint: If any of the three lengths is greater than the sum of the other two, then you cannot form a triangle. Otherwise, you can.
#
# ##### Sol:

# %%
# Define a function to check if any of the three lengths is greater than the sum of the other two and Print either "Yes" or "No" 
def isTraingle(a,b,c):
    if(a+b < c):
        print("No")
    elif (b+c < a):
        print("No")
    elif(c+a < b):
        print("No")
    else:
        print("Yes")

a = int(input("Enter value of a "))
b = int(input("Enter value of b "))
c = int(input("Enter value of c "))
isTraingle(a,b,c)
# Out:
# Enter value of a 11
# Enter value of b 11
# Enter value of c 13
# Yes

# %% [markdown]
# ##### Question 7
# 7.	Write a function in Python that takes a list of numbers and returns the cumulative sum; that is, a new list where the nth element is the sum of the first n + 1 elements from the original list. [8 Marks]
# Example:
# >>> t = [1, 2, 3]
# >>> cumulative_sum(t) [1, 3, 6]
#
# ##### Sol:

# %%
# Retrun cumulative sum using Numpy's cumsum method
import numpy as np
def cumilative_sum_usingnp(curr_list):
    new_list = np.cumsum(curr_list)
    return new_list
# Retrun cumulative sum by custom implementation
def cumilative_sum(curr_list):
    new_list = curr_list
    value = 0
    j=0
    for i in curr_list:        
        value += i
        new_list[j] = value        
        j += 1
    return new_list

# %%
cumilative_sum([88,15,20,40,15,11])
# Out:
# [88, 103, 123, 163, 178, 189]

# %% [markdown]
# ##### Question 8
# 8.	Write a Python program that reads a file, breaks each line into words, strips whitespace and punctuation from the words, and converts them to uppercase. [10 Marks]
# Hint: The string module provides a string named whitespace, which contains space, tab, new-­‐line, etc., and punctuation which contains the punctuation characters.
#
# import string
#
# string.punctuation '!"#$%&'()*+,-­‐./:;<=>?@[\]^_`{|}~'
#
# Also, you might consider using the string methods strip, replace and translate.
#
#
# ##### Sol:

# %%
import pandas as pd
import string

# Read the txt file
text_file = open(r"C:\00_Rajesh\Assignments\DAPD\ProjectA\text.txt","r")
words_in_text_file = []

for eachline in text_file:
    # Define Translation table with string.punctuation characters as the characters that need to be replaced
    translation = eachline.maketrans("","", string.punctuation)
    # 1. It should be fine even if we don't use the strip() function at the beginning as we are any case splitting the word
    # 2. After stripping the line with white spaces, we convert the line into upper characters and then apply the translation 
    # function to remove the string.punctuation characters
    updated_line = eachline.strip().upper().translate(translation).split()
    words_in_text_file += updated_line
    
print(words_in_text_file)
# Out:
# ['BSHEB', 'WOKE', 'UP', 'AT', '6', 'AM', 'ITS', 'SO', 'EARLY', 'SHE', 'WAS', 'ONLY', '10', 'AWAKE', 'AND', 'BEGAN', 'DRINKING', 'COFFEE', 'IN', 'FRONT', 'OF', 'HER', 'COMP', 'UTER']

# %% [markdown]
# ##### Question 9
# 9. Write a program that searches a directory and all of its subdirectories recursively, and returns a list of complete paths for all files with a given suffix (like .mp3). [8 Marks]
# Hint: os.path provides several useful functions for manipulating file and path names.
#
# ##### Sol:

# %%
import os

dirPath = r"C:\00_Rajesh\Assignments"

files = []
givenSuffix = ".csv"

# Python method walk() generates the file names in a directory tree by walking the tree 
# r=root, d=directories, f = files
for r, d, f in os.walk(dirPath):
    for file in f:
        if givenSuffix in file: # Condition to check if given suffix is present in file name
            files.append(os.path.join(r, file))

for f in files:
    print(f)
# Out:
# C:\00_Rajesh\Assignments\DAPD\ProjectA\earthquake.csv
# C:\00_Rajesh\Assignments\DAPD\ProjectA\Indian_cities.csv
# C:\00_Rajesh\Assignments\ProjectPartA\Export.csv
# C:\00_Rajesh\Assignments\ProjectPartA\GoldData_Analysis - Copy.csv
# C:\00_Rajesh\Assignments\ProjectPartA\GoldData_Analysis.csv
# C:\00_Rajesh\Assignments\ProjectPartA\Submission\GoldData_CSV.csv

# %% [markdown]
# ##### Question 10
# 10) Analyze Earthquakes
#
# The National Earthquake Information Center (NEIC) determines the location and size of all significant earthquakes that occur worldwide and disseminates this information immediately to national and international agencies, scientists, critical facilities, and the general public. The NEIC compiles and provides to scientists and to the public an extensive seismic database that serves as a foundation for scientific research through the operation of modern digital national and global seismograph networks and cooperative international agreements. The NEIC is the national data center and archive for earthquake information.
# This dataset includes a record of the date, time, location, depth, magnitude, and source of every earthquake with a reported magnitude 5.5 or higher since 1965.
#
# Conduct an EDA on the dataset and try to uncover meaningful and/or interesting insights from the dataset.
#
# Note: Submit the analysis in pdf file.
# ##### Sol:

# %%
import numpy as np
import pandas as pd
import calendar
#!conda install -c conda-forge folium=0.5.0 --yes
import folium

# %%
dataeq = pd.read_csv(r"C:\00_Rajesh\python_assignment\earthquake.csv")

# %%
dataeq.head()
# Out:
#          Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0  01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2  01/05/1965  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 3  01/08/1965  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 4  01/09/1965  13:32:50    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 0                     NaN        6.0             MW  ...
# 1                     NaN        5.8             MW  ...
# 2                     NaN        6.2             MW  ...
# 3                     NaN        5.8             MW  ...
# 4                     NaN        5.8             MW  ...
#
#    Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                         NaN            NaN                  NaN
# ...

# %%
dataeq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23412 entries, 0 to 23411
# Data columns (total 21 columns):
# Date                          23412 non-null object
# Time                          23412 non-null object
# Latitude                      23412 non-null float64
# Longitude                     23412 non-null float64
# Type                          23412 non-null object
# Depth                         23412 non-null float64
# Depth Error                   4461 non-null float64
# Depth Seismic Stations        7097 non-null float64
# Magnitude                     23412 non-null float64
# Magnitude Type                23409 non-null object
# Magnitude Error               327 non-null float64
# Magnitude Seismic Stations    2564 non-null float64
# Azimuthal Gap                 7299 non-null float64
# Horizontal Distance           1604 non-null float64
# Horizontal Error              1156 non-null float64
# Root Mean Square              17352 non-null float64
# ...

# %%
dataeq.isnull().sum()
# Out:
# Date                              0
# Time                              0
# Latitude                          0
# Longitude                         0
# Type                              0
# Depth                             0
# Depth Error                   18951
# Depth Seismic Stations        16315
# Magnitude                         0
# Magnitude Type                    3
# Magnitude Error               23085
# Magnitude Seismic Stations    20848
# Azimuthal Gap                 16113
# Horizontal Distance           21808
# Horizontal Error              22256
# Root Mean Square               6060
# ID                                0
# Source                            0
# Location Source                   0
# Magnitude Source                  0
# Status                            0
# dtype: int64

# %%
# We will only be dealing with Date, Time, Latitude, Longitude, Type, Depth, Magnitude fields and we don't have
# any null values in these fields
# Convert date field to date time field for further analysis
dataeq["Date"] = pd.to_datetime(dataeq["Date"],utc=True)

# %%
dataeq["Type"].unique()
# Out:
# array(['Earthquake', 'Nuclear Explosion', 'Explosion', 'Rock Burst'],
#       dtype=object)

# %%
# We will restrict our analytis to only of Type Earth Quakes
data_earthquakes = dataeq[dataeq["Type"] == 'Earthquake']

# %%
data_earthquakes.shape
# Out:
# (23232, 21)

# %%
ploteq1 = data_earthquakes.Magnitude.plot(kind="hist", bins=20)
ploteq1.set_xlabel("Magnitude")
# Out:
# Text(0.5, 0, 'Magnitude')

# %%
scatterplot1 = data_earthquakes.plot.scatter(x="Magnitude",y="Depth",c="Red")

# %%
earthquakesForEachYear = data_earthquakes.groupby(data_earthquakes.Date.map(lambda x: x.year))['Type'].count()

# %%
earthquakesForEachYear = earthquakesForEachYear.to_frame()
earthquakesForEachYear.head(5)
# Out:
#       Type
# Date
# 1965   339
# 1966   233
# 1967   255
# 1968   303
# 1969   322

# %%
earthquakesForEachYear.columns = ["No. of Earth quakes per year"]

# %%
earthquakesForEachYear.columns
# Out:
# Index(['No. of Earth quakes per year'], dtype='object')

# %%
plot1 = earthquakesForEachYear.plot()
plot1.set_xlabel("Year")
plot1.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
earthquakesPerMonth = dataeq.groupby(dataeq.Date.map(lambda x: x.month))['Type'].count()

# %%
earthquakesPerMonth = earthquakesPerMonth.to_frame()
earthquakesPerMonth.columns = ["No. of Earth quakes by Month"]

# %%
plot2 = earthquakesPerMonth.plot(kind="bar",figsize=(12,6))
plot2.set_xlabel("Month")
plot2.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# Plot earthquakes that occured after year 2015
data_earthquakesgrt2015 = data_earthquakes[data_earthquakes.Date.map(lambda x: x.year) > 2015]
data_earthquakesgrt2015.shape
# Out:
# (469, 21)

# %%
# define the world map
world_map = folium.Map()

# instantiate a feature group for the earth quakes in the dataframe
earthquakes = folium.map.FeatureGroup()

# loop through the 100 crimes and add each to the incidents feature group
for lat, lng, in zip(data_earthquakesgrt2015.Latitude, data_earthquakesgrt2015.Longitude):
    earthquakes.add_child(
        folium.features.CircleMarker(
            [lat, lng],
            radius=2, # define how big you want the circle markers to be
            color='yellow',
            fill=False,
            fill_color='blue',
            fill_opacity=0.6
        )
    )

# Add earthquakes list to the map
world_map.add_child(earthquakes)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
data_earthquakesmagnitudegrt6 = data_earthquakes[data_earthquakes.Magnitude > 7]
data_earthquakesmagnitudegrt6.shape
# Out:
# (570, 21)

# %%
# define the world map
world_map = folium.Map(zoom_start=6)

# instantiate a feature group for the earth quakes in the dataframe
earthquakes = folium.map.FeatureGroup()

# loop through the 100 crimes and add each to the incidents feature group
for lat, lng, in zip(data_earthquakesmagnitudegrt6.Latitude, data_earthquakesmagnitudegrt6.Longitude):
    earthquakes.add_child(
        folium.features.CircleMarker(
            [lat, lng],
            radius=2, # define how big you want the circle markers to be
            color='red',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )

# Add earthquakes list to the map
world_map.add_child(earthquakes)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ##### Question 11
# 11) The dataset contains data on Indian cities (sourced from Govt of India website) and has information about various characteristics.
# Columns for the dataset are as follows:
# Conduct an EDA on the dataset and try to uncover meaningful and/or interesting insights from the dataset. Before conducting the EDA state the questions that you would want to address from the dataset, and then conduct analyses accordingly.
#
# ##### Sol:

# %%
import numpy as np
import pandas as pd
#import matplotlib.pyplot as plt
# Matplotlib and associated plotting modules
#import matplotlib.cm as cm
#import matplotlib.colors as colors
#!conda install -c conda-forge folium=0.5.0 --yes
import folium
#%pylab inline

# %%
data = pd.read_csv(r"C:\00_Rajesh\python_assignment\Indian_cities.csv")

# %%
data.shape
# Out:
# (493, 22)

# %%
data.head()
# Out:
#   name_of_city  state_code      state_name  dist_code  population_total  \
# 0      Abohar            3          PUNJAB          9            145238
# 1    Achalpur           27     MAHARASHTRA          7            112293
# 2    Adilabad           28  ANDHRA PRADESH          1            117388
# 3   Adityapur           20       JHARKHAND         24            173988
# 4       Adoni           28  ANDHRA PRADESH         21            166537
#
#    population_male  population_female  0-6_population_total  \
# 0            76840              68398                 15870
# 1            58256              54037                 11810
# 2            59232              58156                 13103
# 3            91495              82493                 23042
# 4            82743              83794                 18406
#
#    0-6_population_male  0-6_population_female  ...  literates_female  \
# 0                 8587                   7283  ...             44972
# ...

# %%
data.describe(include=['O'])
# Out:
#        name_of_city     state_name              location
# count           493            493                   493
# unique          492             29                   490
# top     Aurangabad   UTTAR PRADESH  26.449923,80.3318736
# freq              2             63                     2

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 493 entries, 0 to 492
# Data columns (total 22 columns):
# name_of_city                      493 non-null object
# state_code                        493 non-null int64
# state_name                        493 non-null object
# dist_code                         493 non-null int64
# population_total                  493 non-null int64
# population_male                   493 non-null int64
# population_female                 493 non-null int64
# 0-6_population_total              493 non-null int64
# 0-6_population_male               493 non-null int64
# 0-6_population_female             493 non-null int64
# literates_total                   493 non-null int64
# literates_male                    493 non-null int64
# literates_female                  493 non-null int64
# sex_ratio                         493 non-null int64
# child_sex_ratio                   493 non-null int64
# effective_literacy_rate_total     493 non-null float64
# ...

# %%
data.nunique()
# Out:
# name_of_city                      492
# state_code                         29
# state_name                         29
# dist_code                          61
# population_total                  493
# population_male                   493
# population_female                 493
# 0-6_population_total              491
# 0-6_population_male               489
# 0-6_population_female             480
# literates_total                   492
# literates_male                    493
# literates_female                  490
# sex_ratio                         195
# child_sex_ratio                   179
# effective_literacy_rate_total     435
# effective_literacy_rate_male      413
# effective_literacy_rate_female    444
# location                          490
# total_graduates                   489
# male_graduates                    485
# female_graduates                  486
# dtype: int64

# %%
data.isnull().sum()
# Out:
# name_of_city                      0
# state_code                        0
# state_name                        0
# dist_code                         0
# population_total                  0
# population_male                   0
# population_female                 0
# 0-6_population_total              0
# 0-6_population_male               0
# 0-6_population_female             0
# literates_total                   0
# literates_male                    0
# literates_female                  0
# sex_ratio                         0
# child_sex_ratio                   0
# effective_literacy_rate_total     0
# effective_literacy_rate_male      0
# effective_literacy_rate_female    0
# location                          0
# total_graduates                   0
# male_graduates                    0
# female_graduates                  0
# dtype: int64

# %%
data["population_male_ratio"] = data.population_male/data.population_total
data["population_female_ratio"] = data.population_female/data.population_total
data["0_6_population_male_ratio"] = data['0-6_population_male']/data['0-6_population_total']
data["0_6_population_female_ratio"] = data['0-6_population_female']/data['0-6_population_total']
data["male_graduates_ratio"] = data.male_graduates/data.total_graduates
data["female_graduates_ratio"] = data.female_graduates/data.total_graduates

# %%
top_10_populated_cities = data[["population_total","name_of_city"]].sort_values(by="population_total",ascending=False)[:10]
bottom_10_populated_cities = data[["population_total","name_of_city"]].sort_values(by="population_total",ascending=True)[:10]

# %%
top_10_populated_cities
# Out:
#      population_total        name_of_city
# 185          12478447     Greater Mumbai
# 141          11007835              Delhi
# 72            8425970           Bengaluru
# 184           6809970  Greater Hyderabad
# 7             5570585          Ahmadabad
# 119           4681087            Chennai
# 274           4486679            Kolkata
# 449           4462002              Surat
# 380           3115431               Pune
# 225           3073350             Jaipur

# %%
bottom_10_populated_cities
# Out:
#      population_total name_of_city
# 332            100036       Nagda
# 53             100128    Banswara
# 211            100416  Hinganghat
# 136            100466       Datia
# 376            100608  Port Blair
# 331            100618      Nagaur
# 247            100620     Kalyani
# 257            101241     Kasganj
# 77             101334  Bhadreswar
# 34             101520  Aurangabad

# %%
# Split location into latitude & longitude values
lat = []
lon = []

for row in data.location:
    try:
        lat.append(row.split(',')[0])
        lon.append(row.split(',')[1])
    except:
        lat.append(np.NaN)
        lon.append(np.NaN)

# Create two new columns from lat and lon
data['latitude'] = lat
data['longitude'] = lon

data['latitude'] = data.latitude.astype(float)
data['longitude'] = data.longitude.astype(float)

# %%
# define the world map
world_map = folium.Map(location=[21.14, 79.08],zoom_start=5)

top_10_populated_cities = data.sort_values(by="population_total",ascending=False)[:20]

city_population = top_10_populated_cities

# instantiate a feature group for the indian cities in the dataframe
indian_cities = folium.map.FeatureGroup()

# loop through the 100 crimes and add each to the incidents feature group
for lat, lng,poptotal, in zip(city_population.latitude, city_population.longitude,city_population.population_total):
    indian_cities.add_child(
        folium.features.CircleMarker(
            [lat, lng],
            radius=(poptotal*15)/10000000, # define how big you want the circle markers to be
            color='yellow',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )

# Add earthquakes list to the map
world_map.add_child(indian_cities)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# define the world map
world_map = folium.Map(location=[21.14, 79.08],zoom_start=5)

top_20_high_literacy_rate = data.sort_values(by="effective_literacy_rate_total",ascending=False)[:20]

city_population = top_20_high_literacy_rate

# instantiate a feature group for the indian cities in the dataframe
indian_cities = folium.map.FeatureGroup()

# loop through the 100 crimes and add each to the incidents feature group
for lat, lng,poptotal, in zip(city_population.latitude, city_population.longitude,city_population.population_total):
    indian_cities.add_child(
        folium.features.CircleMarker(
            [lat, lng],
            radius=10, # define how big you want the circle markers to be
            color='yellow',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )

# Add earthquakes list to the map
world_map.add_child(indian_cities)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# define the world map
world_map = folium.Map(location=[21.14, 79.08],zoom_start=5)

bottom_20_high_literacy_rate = data.sort_values(by="effective_literacy_rate_total",ascending=True)[:20]

city_population = bottom_20_high_literacy_rate

# instantiate a feature group for the indian cities in the dataframe
indian_cities = folium.map.FeatureGroup()

# loop through the 100 crimes and add each to the incidents feature group
for lat, lng,poptotal, in zip(city_population.latitude, city_population.longitude,city_population.population_total):
    indian_cities.add_child(
        folium.features.CircleMarker(
            [lat, lng],
            radius=10, # define how big you want the circle markers to be
            color='yellow',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )

# Add earthquakes list to the map
world_map.add_child(indian_cities)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# define the world map
world_map = folium.Map(location=[21.14, 79.08],zoom_start=5)

bottom_20_female_population_ratio = data.sort_values(by="population_female_ratio",ascending=True)[:20]

city_population = bottom_20_female_population_ratio

# instantiate a feature group for the indian cities in the dataframe
indian_cities = folium.map.FeatureGroup()

# loop through the 100 crimes and add each to the incidents feature group
for lat, lng,poptotal, in zip(city_population.latitude, city_population.longitude,city_population.population_total):
    indian_cities.add_child(
        folium.features.CircleMarker(
            [lat, lng],
            radius=10, # define how big you want the circle markers to be
            color='yellow',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )

# Add earthquakes list to the map
world_map.add_child(indian_cities)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# define the world map
world_map = folium.Map(location=[21.14, 79.08],zoom_start=5)

top_20_population_female_ratio = data.sort_values(by="population_female_ratio",ascending=False)[:20]

city_population = top_20_population_female_ratio

# instantiate a feature group for the indian cities in the dataframe
indian_cities = folium.map.FeatureGroup()

# loop through the 100 crimes and add each to the incidents feature group
for lat, lng,poptotal, in zip(city_population.latitude, city_population.longitude,city_population.population_total):
    indian_cities.add_child(
        folium.features.CircleMarker(
            [lat, lng],
            radius=10, # define how big you want the circle markers to be
            color='yellow',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )

# Add earthquakes list to the map
world_map.add_child(indian_cities)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Let's check if high effective literacy rate has any coorelation with high female ratio
scatterplot1 = data.plot.scatter(x="effective_literacy_rate_total",y="population_female_ratio",c="Red")

# %%
data_ef_po = data.loc[:,["effective_literacy_rate_total","population_female_ratio"]]
data_ef_po.corr()
# Out:
#                                effective_literacy_rate_total  \
# effective_literacy_rate_total                       1.000000
# population_female_ratio                             0.249401
#
#                                population_female_ratio
# effective_literacy_rate_total                 0.249401
# population_female_ratio                       1.000000

# %%
# define the world map
world_map = folium.Map(location=[21.14, 79.08],zoom_start=5)

bottom_20_0_6_population_female_ratio = data.sort_values(by="0_6_population_female_ratio",ascending=True)[:20]

city_population = bottom_20_0_6_population_female_ratio

# instantiate a feature group for the indian cities in the dataframe
indian_cities = folium.map.FeatureGroup()

# loop through the 100 crimes and add each to the incidents feature group
for lat, lng,poptotal, in zip(city_population.latitude, city_population.longitude,city_population.population_total):
    indian_cities.add_child(
        folium.features.CircleMarker(
            [lat, lng],
            radius=10, # define how big you want the circle markers to be
            color='yellow',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )

# Add earthquakes list to the map
world_map.add_child(indian_cities)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
bottom_20_0_6_population_female_ratio["0_6_population_female_ratio"].head(20)
# Out:
# 296    0.432543
# 6      0.435550
# 313    0.437628
# 159    0.438529
# 41     0.439482
# 404    0.439635
# 442    0.440683
# 407    0.442196
# 428    0.443748
# 369    0.445169
# 227    0.446143
# 438    0.446406
# 256    0.446518
# 316    0.446738
# 171    0.447085
# 90     0.447105
# 449    0.448361
# 172    0.448845
# 362    0.450006
# 149    0.450026
# Name: 0_6_population_female_ratio, dtype: float64
