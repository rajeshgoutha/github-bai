# %% [markdown]
# Through this exercise, we will aim to
#
# + Understand type of data we receive from Twitter
# + How to remove columns in a data frame
# + Prepare a dataframe with following columns: Company Name, Shorthand name, Description of company, number of tweets by each company
# + Find out if a company manages multiple twitter accounts
# + Find out number of original tweets in the dataset and create a dataframe
# + Count hashtags
# + Generate factor variables in Python
# + Analyze reaction to tweets
# + Perform a basic modeling
# + Analyze time series behavior of tweets

# %%
#We first import the packages that we would need for this case study
import numpy as np
import pandas as pd
from pandas import DataFrame
from pandas import Series
import matplotlib
# %matplotlib inline

# %%
#Reading in data and looking at the number of rows and columns using shape 
twitter = pd.read_csv(r'C:\01 Projects\07 Personal_Projects\00 ISB Course\Python\Session 4\twitter_data.csv', sep=',')
twitter.shape
# Out:
# (34097, 60)

# %%
twitter.head()
# Out:
#    rowid            query            tweet_id        tweet_id_str  \
# 0  67340   humanavitality  306897327585652736  306897327585652736
# 1  39454  FundacionPfizer  308616393706844160  308616393706844160
# 2   2812  FundacionPfizer  388441368324218881  388441368324218881
# 3  51601    Intelinvolved  326836137731694592  326836137731694592
# 4  54665         CiscoCSR  381770853824090112  381770853824090112
#
#                 inserted_date  truncated language  possibly_sensitive  \
# 0  2014-03-09 13:46:50.222857          0       en                 NaN
# 1  2014-03-09 13:38:20.679967          0       es                 NaN
# 2  2014-01-11 20:02:04.509695          0       es                 0.0
# 3  2014-03-09 13:41:32.077436          0       en                 0.0
# 4  2014-03-09 13:42:42.821992          0       en                 0.0
#
#   coordinates retweeted_status  ...  retweeted_user_screen_name  \
# 0         NaN              NaN  ...                         NaN
# 1         NaN              NaN  ...                         NaN
# 2         NaN              NaN  ...                         NaN
# 3         NaN              NaN  ...                         NaN
# 4         NaN              NaN  ...                         NaN
#
#    retweeted_user_followers_count retweeted_user_listed_count  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                             NaN                         NaN
# 3                             NaN                         NaN
# 4                             NaN                         NaN
#
#   retweeted_user_statuses_count  retweeted_user_location  \
# 0                           NaN                      NaN
# 1                           NaN                      NaN
# 2                           NaN                      NaN
# 3                           NaN                      NaN
# 4                           NaN                      NaN
#
#    retweeted_tweet_created_at Fortune_2012_rank        Company  \
# 0                         NaN                79         Humana
# 1                         NaN                40         Pfizer
# 2                         NaN                40         Pfizer
# 3                         NaN                51          Intel
# 4                         NaN                64  Cisco Systems
#
#    CSR_sustainability  specific_project_initiative_area
# 0                   0                                 1
# 1                   0                                 1
# 2                   0                                 1
# 3                   1                                 0
# 4                   1                                 0
#
# [5 rows x 60 columns]

# %%
#Removing columns we are not interested in
twitter = twitter.drop('created_at_text',1)
twitter = twitter.drop('tweet_id',1)

# %%
#Identify unique user names that are tweeting
twitter['from_user_screen_name'].unique()
# Out:
# array(['humanavitality', 'FundacionPfizer', 'Intelinvolved', 'CiscoCSR',
#        'IBMSmartCities', 'citizenIBM', 'BofA_Community', 'PG_CSDW',
#        'mathmovesu', 'PPGIdeascapes', 'gehealthy', 'msftcitizenship',
#        'TICalculators', 'CiscoEDU', 'DuPont_ability', 'Dell4Good',
#        'verizongiving', 'DellEDU', 'SprintGreenNews', 'TeachingMoney',
#        'WalmartGreen', 'ecomagination', 'WalmartAction',
#        'Microsoft_Green', 'Comcastdreambig', 'DE_Youtility',
#        'hpglobalcitizen', 'CitizenDisney', 'AmgenFoundation', 'ATTAspire',
#        'AlcoaFoundation', 'nikebetterworld', 'HoneywellBuild',
#        'googlestudents', '3M_FoodSafety', 'HeartRescue', 'EnviroSears',
#        'ClickToEmpower', 'GreenIBM', 'PromesaPepsiCo', 'FordDriveGreen',
#        'JNJStories'], dtype=object)

# %%
len(twitter['from_user_screen_name'].unique())
# Out:
# 42

# %%
def f(x):
     return Series(dict(Number_of_tweets = x['content'].count(), 
                        Company=x['Company'].min(),
                        Description=x['from_user_description'].min(),
                        ))

# %%
company_count = twitter.groupby('from_user_screen_name').apply(f) 
print(len(company_count))
# Out:
# 42

# %%
company_count
# Out:
#                        Number_of_tweets                          Company  \
# from_user_screen_name
# 3M_FoodSafety                       325                               3M
# ATTAspire                           336                             AT&T
# AlcoaFoundation                    1053                            Alcoa
# AmgenFoundation                     135                            Amgen
# BofA_Community                     1722            Bank of America Corp.
# CiscoCSR                           2511                    Cisco Systems
# CiscoEDU                            932                    Cisco Systems
# CitizenDisney                       211                      Walt Disney
# ClickToEmpower                      149                         Allstate
# Comcastdreambig                     581                          Comcast
# DE_Youtility                        300                      Duke Energy
# Dell4Good                           829                             Dell
# DellEDU                            1108                             Dell
# DuPont_ability                     1509                           DuPont
# EnviroSears                          53                   Sears Holdings
# FordDriveGreen                       27                       Ford Motor
# FundacionPfizer                     421                           Pfizer
# GreenIBM                             81  International Business Machines
# HeartRescue                         322                        Medtronic
# HoneywellBuild                      242          Honeywell International
# IBMSmartCities                     1570  International Business Machines
# Intelinvolved                      1524                            Intel
# JNJStories                            9                Johnson & Johnson
# Microsoft_Green                     436                        Microsoft
# PG_CSDW                             187                 Procter & Gamble
# PPGIdeascapes                       160                   PPG Industries
# PromesaPepsiCo                        7                          PepsiCo
# SprintGreenNews                     201                    Sprint Nextel
# TICalculators                      1767                Texas Instruments
# TeachingMoney                       187            Capital One Financial
# WalmartAction                      1915                  Wal-Mart Stores
# WalmartGreen                       1434                  Wal-Mart Stores
# citizenIBM                         1039  International Business Machines
# ecomagination                       594                 General Electric
# gehealthy                          2461                 General Electric
# googlestudents                      211                           Google
# hpglobalcitizen                     470                  Hewlett-Packard
# humanavitality                      762                           Humana
# mathmovesu                         1146                         Raytheon
# msftcitizenship                    2493                        Microsoft
# nikebetterworld                     153                             Nike
# verizongiving                      2524           Verizon Communications
#
#                                                              Description
# from_user_screen_name
# 3M_FoodSafety          3M Food Safety | global manufacturer of innova...
# ATTAspire                    Inspiring students to achieve their dreams.
# AlcoaFoundation        Since 1952, we’ve invested $570 million to imp...
# AmgenFoundation        The Amgen Foundation seeks to advance science ...
# BofA_Community         We’re connecting local communities to the peop...
# CiscoCSR               Sharing stories about how Cisco and our partne...
# CiscoEDU               Tweets on the Cisco Connected Learning Experie...
# CitizenDisney          We believe in the power of stories, families a...
# ClickToEmpower         Click to Empower is a Web initiative of The Al...
# Comcastdreambig        Comcast empowers communities across the countr...
# DE_Youtility           This profile will retire soon, so head on over...
# Dell4Good              News from Dell corp. responsibility team: sust...
# DellEDU                Connecting with students, educators, school ad...
# DuPont_ability         DuPont sustainability news: clean energy, sola...
# EnviroSears            Discussing sustainability topics at Sears Hold...
# FordDriveGreen         Ford is committed to affordable, sustainable p...
# FundacionPfizer        Noticias sobre Responsabilidad Social y Fundac...
# GreenIBM               Official Twitter account for IBM Big Green Inn...
# HeartRescue            A collaborative effort supported by the Medtro...
# HoneywellBuild         Honeywell Building Solutions installs, integra...
# IBMSmartCities         Official IBM Smarter Cities account. Managed b...
# Intelinvolved          Connecting & enriching lives worldwide to crea...
# JNJStories             We're tweeting about social good over on @JNJC...
# Microsoft_Green        The official Twitter account for Microsoft's E...
# PG_CSDW                News from P&G's Children’s Safe Drinking Water...
# PPGIdeascapes          PPG Ideascapes provides sustainable building p...
# PromesaPepsiCo         PepsiCo's commitment to the Hispanic community...
# SprintGreenNews        News and Information about Sprint's sustainabi...
# TICalculators          Texas Instruments works w/ educators in design...
# TeachingMoney          Teaching Money is a new initiative created to ...
# WalmartAction          Our Community Action Network works to improve ...
# WalmartGreen           Together, we can create a sustainable world & ...
# citizenIBM             This official Citizen IBM Twitter feed is admi...
# ecomagination          A forum for fresh thinking and conversation ab...
# gehealthy              A shared commitment to creating better health ...
# googlestudents         Google news and updates especially for student...
# hpglobalcitizen        HP Living Progress is focused to create a bett...
# humanavitality         This is the official Twitter account for Human...
# mathmovesu             We represent the centerpiece citizenship initi...
# msftcitizenship        Sharing stories about how Microsoft and our pa...
# nikebetterworld        A better world needs the world’s biggest team....
# verizongiving          We are focused on using technology to solve cr...

# %%
#Let us see how many twitter handles each company uses
counts = company_count.groupby('Company').size()
counts
# Out:
# Company
# 3M                                 1
# AT&T                               1
# Alcoa                              1
# Allstate                           1
# Amgen                              1
# Bank of America Corp.              1
# Capital One Financial              1
# Cisco Systems                      2
# Comcast                            1
# Dell                               2
# DuPont                             1
# Duke Energy                        1
# Ford Motor                         1
# General Electric                   2
# Google                             1
# Hewlett-Packard                    1
# Honeywell International            1
# Humana                             1
# Intel                              1
# International Business Machines    3
# Johnson & Johnson                  1
# Medtronic                          1
# Microsoft                          2
# Nike                               1
# PPG Industries                     1
# PepsiCo                            1
# Pfizer                             1
# Procter & Gamble                   1
# Raytheon                           1
# Sears Holdings                     1
# Sprint Nextel                      1
# Texas Instruments                  1
# Verizon Communications             1
# Wal-Mart Stores                    2
# Walt Disney                        1
# dtype: int64

# %%
#Number of tweets posted by each company. Any pattern here?
company_count = company_count.sort_values(['Number_of_tweets'], ascending=False)
company_count
# Out:
#                        Number_of_tweets                          Company  \
# from_user_screen_name
# verizongiving                      2524           Verizon Communications
# CiscoCSR                           2511                    Cisco Systems
# msftcitizenship                    2493                        Microsoft
# gehealthy                          2461                 General Electric
# WalmartAction                      1915                  Wal-Mart Stores
# TICalculators                      1767                Texas Instruments
# BofA_Community                     1722            Bank of America Corp.
# IBMSmartCities                     1570  International Business Machines
# Intelinvolved                      1524                            Intel
# DuPont_ability                     1509                           DuPont
# WalmartGreen                       1434                  Wal-Mart Stores
# mathmovesu                         1146                         Raytheon
# DellEDU                            1108                             Dell
# AlcoaFoundation                    1053                            Alcoa
# citizenIBM                         1039  International Business Machines
# CiscoEDU                            932                    Cisco Systems
# Dell4Good                           829                             Dell
# humanavitality                      762                           Humana
# ecomagination                       594                 General Electric
# Comcastdreambig                     581                          Comcast
# hpglobalcitizen                     470                  Hewlett-Packard
# Microsoft_Green                     436                        Microsoft
# FundacionPfizer                     421                           Pfizer
# ATTAspire                           336                             AT&T
# 3M_FoodSafety                       325                               3M
# HeartRescue                         322                        Medtronic
# DE_Youtility                        300                      Duke Energy
# HoneywellBuild                      242          Honeywell International
# CitizenDisney                       211                      Walt Disney
# googlestudents                      211                           Google
# SprintGreenNews                     201                    Sprint Nextel
# TeachingMoney                       187            Capital One Financial
# PG_CSDW                             187                 Procter & Gamble
# PPGIdeascapes                       160                   PPG Industries
# nikebetterworld                     153                             Nike
# ClickToEmpower                      149                         Allstate
# AmgenFoundation                     135                            Amgen
# GreenIBM                             81  International Business Machines
# EnviroSears                          53                   Sears Holdings
# FordDriveGreen                       27                       Ford Motor
# JNJStories                            9                Johnson & Johnson
# PromesaPepsiCo                        7                          PepsiCo
#
#                                                              Description
# from_user_screen_name
# verizongiving          We are focused on using technology to solve cr...
# CiscoCSR               Sharing stories about how Cisco and our partne...
# msftcitizenship        Sharing stories about how Microsoft and our pa...
# gehealthy              A shared commitment to creating better health ...
# WalmartAction          Our Community Action Network works to improve ...
# TICalculators          Texas Instruments works w/ educators in design...
# BofA_Community         We’re connecting local communities to the peop...
# IBMSmartCities         Official IBM Smarter Cities account. Managed b...
# Intelinvolved          Connecting & enriching lives worldwide to crea...
# DuPont_ability         DuPont sustainability news: clean energy, sola...
# WalmartGreen           Together, we can create a sustainable world & ...
# mathmovesu             We represent the centerpiece citizenship initi...
# DellEDU                Connecting with students, educators, school ad...
# AlcoaFoundation        Since 1952, we’ve invested $570 million to imp...
# citizenIBM             This official Citizen IBM Twitter feed is admi...
# CiscoEDU               Tweets on the Cisco Connected Learning Experie...
# Dell4Good              News from Dell corp. responsibility team: sust...
# humanavitality         This is the official Twitter account for Human...
# ecomagination          A forum for fresh thinking and conversation ab...
# Comcastdreambig        Comcast empowers communities across the countr...
# hpglobalcitizen        HP Living Progress is focused to create a bett...
# Microsoft_Green        The official Twitter account for Microsoft's E...
# FundacionPfizer        Noticias sobre Responsabilidad Social y Fundac...
# ATTAspire                    Inspiring students to achieve their dreams.
# 3M_FoodSafety          3M Food Safety | global manufacturer of innova...
# HeartRescue            A collaborative effort supported by the Medtro...
# DE_Youtility           This profile will retire soon, so head on over...
# HoneywellBuild         Honeywell Building Solutions installs, integra...
# CitizenDisney          We believe in the power of stories, families a...
# googlestudents         Google news and updates especially for student...
# SprintGreenNews        News and Information about Sprint's sustainabi...
# TeachingMoney          Teaching Money is a new initiative created to ...
# PG_CSDW                News from P&G's Children’s Safe Drinking Water...
# PPGIdeascapes          PPG Ideascapes provides sustainable building p...
# nikebetterworld        A better world needs the world’s biggest team....
# ClickToEmpower         Click to Empower is a Web initiative of The Al...
# AmgenFoundation        The Amgen Foundation seeks to advance science ...
# GreenIBM               Official Twitter account for IBM Big Green Inn...
# EnviroSears            Discussing sustainability topics at Sears Hold...
# FordDriveGreen         Ford is committed to affordable, sustainable p...
# JNJStories             We're tweeting about social good over on @JNJC...
# PromesaPepsiCo         PepsiCo's commitment to the Hispanic community...

# %%
company_count['Number_of_tweets'].plot(kind='bar')

# %%
import calendar

# %%
twitter.head(2)
# Out:
#    rowid            query        tweet_id_str               inserted_date  \
# 0  67340   humanavitality  306897327585652736  2014-03-09 13:46:50.222857
# 1  39454  FundacionPfizer  308616393706844160  2014-03-09 13:38:20.679967
#
#    truncated language  possibly_sensitive coordinates retweeted_status  \
# 0          0       en                 NaN         NaN              NaN
# 1          0       es                 NaN         NaN              NaN
#
#    withheld_in_countries  ...  retweeted_user_screen_name  \
# 0                    NaN  ...                         NaN
# 1                    NaN  ...                         NaN
#
#   retweeted_user_followers_count  retweeted_user_listed_count  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
#
#    retweeted_user_statuses_count retweeted_user_location  \
# 0                            NaN                     NaN
# 1                            NaN                     NaN
#
#   retweeted_tweet_created_at  Fortune_2012_rank  Company  CSR_sustainability  \
# 0                        NaN                 79   Humana                   0
# 1                        NaN                 40   Pfizer                   0
#
#    specific_project_initiative_area
# 0                                 1
# 1                                 1
#
# [2 rows x 58 columns]

# %%
twitter.dtypes
# Out:
# rowid                                 int64
# query                                object
# tweet_id_str                          int64
# inserted_date                        object
# truncated                             int64
# language                             object
# possibly_sensitive                  float64
# coordinates                          object
# retweeted_status                     object
# withheld_in_countries               float64
# withheld_scope                      float64
# created_at                           object
# month                                 int64
# year                                  int64
# content                              object
# from_user_screen_name                object
# from_user_id                          int64
# from_user_followers_count             int64
# from_user_friends_count               int64
# from_user_listed_count                int64
# from_user_favourites_count            int64
# from_user_statuses_count              int64
# from_user_description                object
# from_user_location                   object
# from_user_created_at                 object
# retweet_count                         int64
# favorite_count                        int64
# entities_urls                        object
# entities_urls_count                   int64
# entities_hashtags                    object
# entities_hashtags_count               int64
# entities_mentions                    object
# entities_mentions_count               int64
# in_reply_to_screen_name              object
# in_reply_to_status_id               float64
# source                               object
# entities_expanded_urls               object
# entities_media_count                float64
# media_expanded_url                   object
# media_url                            object
# media_type                           object
# video_link                            int64
# photo_link                            int64
# twitpic                               int64
# num_characters                        int64
# num_words                             int64
# retweeted_user                      float64
# retweeted_user_description           object
# retweeted_user_screen_name           object
# retweeted_user_followers_count      float64
# retweeted_user_listed_count         float64
# retweeted_user_statuses_count       float64
# retweeted_user_location              object
# retweeted_tweet_created_at           object
# Fortune_2012_rank                     int64
# Company                              object
# CSR_sustainability                    int64
# specific_project_initiative_area      int64
# dtype: object

# %%
twitter['created_at'].head()
# Out:
# 0    2013-02-27 22:43:19.000000
# 1    2013-03-04 16:34:17.000000
# 2    2013-10-10 23:10:13.000000
# 3    2013-04-23 23:13:02.000000
# 4    2013-09-22 13:23:59.000000
# Name: created_at, dtype: object

# %%
twitter['created_at'] = pd.to_datetime(twitter['created_at'])

# %%
twitter = twitter.set_index(['created_at'])
twitter.head(2)
# Out:
#                      rowid            query        tweet_id_str  \
# created_at
# 2013-02-27 22:43:19  67340   humanavitality  306897327585652736
# 2013-03-04 16:34:17  39454  FundacionPfizer  308616393706844160
#
#                                   inserted_date  truncated language  \
# created_at
# 2013-02-27 22:43:19  2014-03-09 13:46:50.222857          0       en
# 2013-03-04 16:34:17  2014-03-09 13:38:20.679967          0       es
#
#                      possibly_sensitive coordinates retweeted_status  \
# created_at
# 2013-02-27 22:43:19                 NaN         NaN              NaN
# 2013-03-04 16:34:17                 NaN         NaN              NaN
#
#                      withheld_in_countries  ...  retweeted_user_screen_name  \
# created_at                                  ...
# 2013-02-27 22:43:19                    NaN  ...                         NaN
# 2013-03-04 16:34:17                    NaN  ...                         NaN
#
#                      retweeted_user_followers_count  \
# created_at
# 2013-02-27 22:43:19                             NaN
# 2013-03-04 16:34:17                             NaN
#
#                      retweeted_user_listed_count  \
# created_at
# 2013-02-27 22:43:19                          NaN
# 2013-03-04 16:34:17                          NaN
#
#                     retweeted_user_statuses_count retweeted_user_location  \
# created_at
# 2013-02-27 22:43:19                           NaN                     NaN
# 2013-03-04 16:34:17                           NaN                     NaN
#
#                      retweeted_tweet_created_at  Fortune_2012_rank  Company  \
# created_at
# 2013-02-27 22:43:19                         NaN                 79   Humana
# 2013-03-04 16:34:17                         NaN                 40   Pfizer
#
#                      CSR_sustainability  specific_project_initiative_area
# created_at
# 2013-02-27 22:43:19                   0                                 1
# 2013-03-04 16:34:17                   0                                 1
#
# [2 rows x 57 columns]

# %%
def f(x):
     return Series(dict(Number_of_tweets = x['content'].count(), 
))

# %%
daily_count = twitter.groupby(twitter.index.date).apply(f)
print(len(daily_count))
daily_count.index.name = 'date'
daily_count.head(5)
# Out:
# 365
#             Number_of_tweets
# date
# 2013-01-01                24
# 2013-01-02                71
# 2013-01-03                94
# 2013-01-04                97
# 2013-01-05                38

# %%
daily_plot = daily_count['Number_of_tweets'].plot(kind='line')

# %%
weekday_count = twitter.groupby(twitter.index.weekday).apply(f)
print(len(weekday_count))
weekday_count
# Out:
# 7
#             Number_of_tweets
# created_at
# 0                       5520
# 1                       6649
# 2                       7092
# 3                       6475
# 4                       5593
# 5                       1694
# 6                       1074

# %%
hourly_count = twitter.groupby(twitter.index.hour).apply(f)
print(len(hourly_count))
hourly_count
# Out:
# 24
#             Number_of_tweets
# created_at
# 0                       1141
# 1                        914
# 2                        462
# 3                        269
# 4                        201
# 5                        245
# 6                        146
# 7                         93
# 8                        117
# 9                         99
# 10                       183
# 11                       280
# 12                       693
# 13                      1784
# 14                      3057
# 15                      3386
# 16                      3294
# 17                      3000
# 18                      3052
# 19                      3281
# 20                      3061
# 21                      2468
# 22                      1695
# 23                      1176

# %%
hourly_plot = hourly_count['Number_of_tweets'].plot()

# %%
minute_count = twitter.groupby(twitter.index.minute).apply(f)
print(len(minute_count))
minute_count.head()
# Out:
# 60
#             Number_of_tweets
# created_at
# 0                       3284
# 1                        681
# 2                        656
# 3                        582
# 4                        485

# %%
minute_count.plot()

# %%
second_count = twitter.groupby(twitter.index.second).apply(f)
print(len(second_count))
second_count.head()
# Out:
# 60
#             Number_of_tweets
# created_at
# 0                       1245
# 1                       1672
# 2                       1771
# 3                       1174
# 4                        954

# %%
second_count.plot()
